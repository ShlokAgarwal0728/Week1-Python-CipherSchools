# %%
#delimeter is on;y\n character
a=input()
# Out:
# 123

# %%
print(a)
# Out:
# 123

# %%
type(a)
# Out:
# str

# %%
a=15

# %%
str(a)
# Out:
# '15'

# %%
int("1234")
# Out:
# 1234

# %%
float("123.4")
# Out:
# 123.4

# %%
a = 65

# %%
a = 'A'
