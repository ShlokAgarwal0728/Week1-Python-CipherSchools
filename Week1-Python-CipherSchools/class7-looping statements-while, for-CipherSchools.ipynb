# %%
a = 1
while a < 10:
  print(a)
  a += 1
# Out:
# 1
# 2
# 3
# 4
# 5
# 6
# 7
# 8
# 9

# %%
#while battery.notDead():
#   pas

# %%
iter(object)

# %%
a = "Suryansh"
a.__iter__
# Out:
# <method-wrapper '__iter__' of str object at 0x7fc7215044f0>

# %%
print(type(name))
print("***")

for c in name:
   print(c)
   print(type(c))

# %%
for i in range(5):
  print(i)
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
a = range(5)
print(a)
# Out:
# range(0, 5)

# %%
for i in range(5):
  print(i)
  if i ==3:
    break
# Out:
# 0
# 1
# 2
# 3

# %%
for i in range(5):
  print(i)
  if i ==3:
    break
# Out:
# 0
# 1
# 2
# 3

# %%
for i in range(5):
  print(i)
  del i
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
for i in range(5):
  print(i)
  i = 100
  print(i)
# Out:
# 0
# 100
# 1
# 100
# 2
# 100
# 3
# 100
# 4
# 100

# %%
if True:
  """hfkguhrgouk"""
  print("rest of the code")
# Out:
# rest of the code

# %%
for i in range(5):
  print(i)
else:
  print("something")
# Out:
# 0
# 1
# 2
# 3
# 4
# something

# %%
for i in range(5):
  print(i)
  if i ==3:
    break
else:
  print("something")
# Out:
# 0
# 1
# 2
# 3
